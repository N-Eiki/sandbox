# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym
# from JSAnimation.IPyhton_display import display_animation
from matplotlib import animation
from IPython.display import display

# %%
frames = []
env = gym.make('CartPole-v0')
observation = env.reset()

for step in range(0,200):
    frames.append(env.render(mode='rgb_array'))
    action = np.random.choice(2)
    observation, reward, done, info = env.step(action)
env.close()
# Out:
# /Users/nagataeiki/.pyenv/versions/3.7.4/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
ENV = 'CartPole-v0'
NUM_DIZITIZED=6
env = gym.make(ENV)
observation = env.reset()

# %%
def bins(clip_min, clip_max, num):
    return np.linspace(clip_min, clip_max, num+1)[1:-1]

# %%
def digitize_state(observation):
    cart_pos, cart_v, pole_angle, pole_v = observation
    digitized = [
        np.digitize(cart_pos, bins=bins(-2.4, 2.4, NUM_DIZITIZED)),
        np.digitize(cart_v,   bins=bins(-3.0, 3.0, NUM_DIZITIZED)),
        np.digitize(pole_angle, bins=bins(-0.5, 0.5, NUM_DIZITIZED)),
        np.digitize(pole_v, bins=bins(-2.0, 2.0, NUM_DIZITIZED)),
    ]
    return sum([x*(NUM_DIZITIZED**i) for i,x in enumerate(digitized)])

# %%
#3.4 Q学習

# %%
ENV = 'CartPole-v0'
NUM_DIZITIZED = 6
GAMMA=0.99
ETA=0.5
MAX_STEPS = 200
NUM_EPISODES=1000

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
        
    def update_Q_function(self, observation, action, reward, observation_next):
        self.brain.update_Q_table(observation, action, reward, observation_next)
        
    def get_action(self, observation, step):
        action = self.brain.decide_action(observation, step)
        return action
    
    
class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))
        
    def bins(self, clip_min, clip_max, num):
        return np.linspace(clip_min, clip_max, num+1)[1:-1]
    
    def digitize_state(self, observation):
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))]
        return sum([x*(NUM_DIZITIZED**i) for i,x in enumerate(digitized)])
    
    def update_Q_table(self, observation, action, reward, observation_next):
        #QテーブルをQ学習で更新
        state = self.digitize_state(observation)
        state_next = self.digitize_state(observation_next)
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + ETA*(reward + GAMMA*Max_Q_next-self.q_table[state, action])
               
    def decide_action(self, observation, episode):
        state = self.digitize_state(observation)
        epsilon = 0.5*(1/(episode+1))
        
        if epsilon <= np.random.uniform(0,1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
        return action

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions= self.env.action_space.n
        self.agent = Agent(num_states, num_actions)
        
    def run(self):
        complete_episodes=0
        is_episode_final = False
        frames = []
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            for step in range(MAX_STEPS):
                if is_episode_final:
                    frames.append(self.env.render(mode='rgb_array'))
                action = self.agent.get_action(observation, episode)
                observation_next, _, done, _ = self.env.step(action)
                if done:
                    if step<195:
                        reward = -1
                        complete_episodes=0
                    else:
                        reward = 1
                        complete_episodes +=1
                else:
                    reward = 0
                self.agent.update_Q_function(
                    observation, action, reward, observation_next)
                observation = observation_next

                if done:
                    print(f'{episode} episode: finished after {step+1} time steps')
                    break
                    
            if is_episode_final:
                break

            if complete_episodes>=10:
                print('10回成功')
                is_episode_final=True
        self.env.close()

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0 episode: finished after 18 time steps
# 1 episode: finished after 13 time steps
# 2 episode: finished after 17 time steps
# 3 episode: finished after 14 time steps
# 4 episode: finished after 8 time steps
# 5 episode: finished after 13 time steps
# 6 episode: finished after 14 time steps
# 7 episode: finished after 24 time steps
# 8 episode: finished after 14 time steps
# 9 episode: finished after 35 time steps
# 10 episode: finished after 28 time steps
# 11 episode: finished after 16 time steps
# 12 episode: finished after 27 time steps
# 13 episode: finished after 36 time steps
# 14 episode: finished after 47 time steps
# 15 episode: finished after 81 time steps
# 16 episode: finished after 70 time steps
# 17 episode: finished after 80 time steps
# 18 episode: finished after 26 time steps
# 19 episode: finished after 39 time steps
# 20 episode: finished after 32 time steps
# 21 episode: finished after 30 time steps
# 22 episode: finished after 106 time steps
# 23 episode: finished after 60 time steps
# 24 episode: finished after 68 time steps
# 25 episode: finished after 72 time steps
# 26 episode: finished after 119 time steps
# 27 episode: finished after 29 time steps
# 28 episode: finished after 156 time steps
# 29 episode: finished after 10 time steps
# 30 episode: finished after 21 time steps
# 31 episode: finished after 36 time steps
# 32 episode: finished after 19 time steps
# 33 episode: finished after 13 time steps
# 34 episode: finished after 39 time steps
# 35 episode: finished after 22 time steps
# 36 episode: finished after 11 time steps
# 37 episode: finished after 9 time steps
# 38 episode: finished after 19 time steps
# 39 episode: finished after 23 time steps
# 40 episode: finished after 13 time steps
# 41 episode: finished after 79 time steps
# 42 episode: finished after 32 time steps
# 43 episode: finished after 10 time steps
# 44 episode: finished after 10 time steps
# 45 episode: finished after 8 time steps
# 46 episode: finished after 41 time steps
# 47 episode: finished after 37 time steps
# 48 episode: finished after 78 time steps
# 49 episode: finished after 11 time steps
# 50 episode: finished after 13 time steps
# 51 episode: finished after 59 time steps
# 52 episode: finished after 43 time steps
# 53 episode: finished after 10 time steps
# 54 episode: finished after 43 time steps
# 55 episode: finished after 200 time steps
# 56 episode: finished after 10 time steps
# 57 episode: finished after 15 time steps
# 58 episode: finished after 103 time steps
# 59 episode: finished after 158 time steps
# 60 episode: finished after 18 time steps
# 61 episode: finished after 40 time steps
# 62 episode: finished after 33 time steps
# 63 episode: finished after 10 time steps
# 64 episode: finished after 20 time steps
# 65 episode: finished after 135 time steps
# 66 episode: finished after 43 time steps
# 67 episode: finished after 126 time steps
# 68 episode: finished after 27 time steps
# 69 episode: finished after 9 time steps
# 70 episode: finished after 13 time steps
# 71 episode: finished after 125 time steps
# 72 episode: finished after 64 time steps
# 73 episode: finished after 32 time steps
# 74 episode: finished after 42 time steps
# 75 episode: finished after 100 time steps
# 76 episode: finished after 95 time steps
# 77 episode: finished after 10 time steps
# 78 episode: finished after 30 time steps
# 79 episode: finished after 35 time steps
# 80 episode: finished after 68 time steps
# 81 episode: finished after 34 time steps
# 82 episode: finished after 174 time steps
# 83 episode: finished after 29 time steps
# 84 episode: finished after 40 time steps
# 85 episode: finished after 200 time steps
# 86 episode: finished after 56 time steps
# 87 episode: finished after 200 time steps
# 88 episode: finished after 94 time steps
# 89 episode: finished after 128 time steps
# 90 episode: finished after 21 time steps
# 91 episode: finished after 88 time steps
# 92 episode: finished after 91 time steps
# 93 episode: finished after 44 time steps
# 94 episode: finished after 40 time steps
# 95 episode: finished after 63 time steps
# 96 episode: finished after 50 time steps
# 97 episode: finished after 99 time steps
# 98 episode: finished after 98 time steps
# 99 episode: finished after 119 time steps
# 100 episode: finished after 88 time steps
# 101 episode: finished after 128 time steps
# 102 episode: finished after 143 time steps
# 103 episode: finished after 120 time steps
# 104 episode: finished after 87 time steps
# 105 episode: finished after 132 time steps
# 106 episode: finished after 84 time steps
# 107 episode: finished after 172 time steps
# 108 episode: finished after 120 time steps
# 109 episode: finished after 90 time steps
# 110 episode: finished after 63 time steps
# 111 episode: finished after 92 time steps
# 112 episode: finished after 146 time steps
# 113 episode: finished after 98 time steps
# 114 episode: finished after 93 time steps
# 115 episode: finished after 138 time steps
# 116 episode: finished after 164 time steps
# 117 episode: finished after 112 time steps
# 118 episode: finished after 103 time steps
# 119 episode: finished after 200 time steps
# 120 episode: finished after 144 time steps
# 121 episode: finished after 191 time steps
# 122 episode: finished after 129 time steps
# 123 episode: finished after 151 time steps
# 124 episode: finished after 157 time steps
# 125 episode: finished after 119 time steps
# 126 episode: finished after 129 time steps
# 127 episode: finished after 144 time steps
# 128 episode: finished after 151 time steps
# 129 episode: finished after 132 time steps
# 130 episode: finished after 143 time steps
# 131 episode: finished after 180 time steps
# 132 episode: finished after 87 time steps
# 133 episode: finished after 95 time steps
# 134 episode: finished after 88 time steps
# 135 episode: finished after 95 time steps
# 136 episode: finished after 167 time steps
# 137 episode: finished after 157 time steps
# 138 episode: finished after 77 time steps
# 139 episode: finished after 129 time steps
# 140 episode: finished after 100 time steps
# 141 episode: finished after 148 time steps
# 142 episode: finished after 143 time steps
# 143 episode: finished after 120 time steps
# 144 episode: finished after 200 time steps
# 145 episode: finished after 44 time steps
# 146 episode: finished after 38 time steps
# 147 episode: finished after 117 time steps
# 148 episode: finished after 183 time steps
# 149 episode: finished after 86 time steps
# 150 episode: finished after 86 time steps
# 151 episode: finished after 76 time steps
# 152 episode: finished after 75 time steps
# 153 episode: finished after 87 time steps
# 154 episode: finished after 141 time steps
# 155 episode: finished after 37 time steps
# 156 episode: finished after 200 time steps
# 157 episode: finished after 47 time steps
# 158 episode: finished after 160 time steps
# 159 episode: finished after 10 time steps
# 160 episode: finished after 42 time steps
# 161 episode: finished after 118 time steps
# 162 episode: finished after 39 time steps
# 163 episode: finished after 200 time steps
# 164 episode: finished after 121 time steps
# 165 episode: finished after 143 time steps
# 166 episode: finished after 96 time steps
# 167 episode: finished after 106 time steps
# 168 episode: finished after 91 time steps
# 169 episode: finished after 75 time steps
# 170 episode: finished after 101 time steps
# 171 episode: finished after 100 time steps
# 172 episode: finished after 59 time steps
# 173 episode: finished after 38 time steps
# 174 episode: finished after 184 time steps
# 175 episode: finished after 118 time steps
# 176 episode: finished after 22 time steps
# 177 episode: finished after 72 time steps
# 178 episode: finished after 73 time steps
# 179 episode: finished after 174 time steps
# 180 episode: finished after 200 time steps
# 181 episode: finished after 157 time steps
# 182 episode: finished after 124 time steps
# 183 episode: finished after 165 time steps
# 184 episode: finished after 134 time steps
# 185 episode: finished after 144 time steps
# 186 episode: finished after 200 time steps
# 187 episode: finished after 140 time steps
# 188 episode: finished after 121 time steps
# 189 episode: finished after 59 time steps
# 190 episode: finished after 160 time steps
# 191 episode: finished after 18 time steps
# 192 episode: finished after 45 time steps
# 193 episode: finished after 47 time steps
# 194 episode: finished after 37 time steps
# 195 episode: finished after 38 time steps
# 196 episode: finished after 47 time steps
# 197 episode: finished after 10 time steps
# 198 episode: finished after 32 time steps
# 199 episode: finished after 79 time steps
# 200 episode: finished after 29 time steps
# 201 episode: finished after 78 time steps
# 202 episode: finished after 51 time steps
# 203 episode: finished after 156 time steps
# 204 episode: finished after 21 time steps
# 205 episode: finished after 91 time steps
# 206 episode: finished after 36 time steps
# 207 episode: finished after 200 time steps
# 208 episode: finished after 50 time steps
# 209 episode: finished after 176 time steps
# 210 episode: finished after 129 time steps
# 211 episode: finished after 171 time steps
# 212 episode: finished after 75 time steps
# 213 episode: finished after 84 time steps
# 214 episode: finished after 165 time steps
# 215 episode: finished after 200 time steps
# 216 episode: finished after 175 time steps
# 217 episode: finished after 157 time steps
# 218 episode: finished after 185 time steps
# 219 episode: finished after 200 time steps
# 220 episode: finished after 200 time steps
# 221 episode: finished after 200 time steps
# 222 episode: finished after 106 time steps
# 223 episode: finished after 153 time steps
# 224 episode: finished after 200 time steps
# 225 episode: finished after 88 time steps
# 226 episode: finished after 200 time steps
# 227 episode: finished after 200 time steps
# 228 episode: finished after 198 time steps
# 229 episode: finished after 125 time steps
# 230 episode: finished after 193 time steps
# 231 episode: finished after 179 time steps
# 232 episode: finished after 110 time steps
# 233 episode: finished after 117 time steps
# 234 episode: finished after 132 time steps
# 235 episode: finished after 200 time steps
# 236 episode: finished after 200 time steps
# 237 episode: finished after 200 time steps
# 238 episode: finished after 200 time steps
# 239 episode: finished after 189 time steps
# 240 episode: finished after 200 time steps
# 241 episode: finished after 200 time steps
# 242 episode: finished after 200 time steps
# 243 episode: finished after 200 time steps
# 244 episode: finished after 200 time steps
# 245 episode: finished after 128 time steps
# 246 episode: finished after 200 time steps
# 247 episode: finished after 200 time steps
# 248 episode: finished after 200 time steps
# 249 episode: finished after 200 time steps
# 250 episode: finished after 200 time steps
# 251 episode: finished after 200 time steps
# 252 episode: finished after 200 time steps
# 253 episode: finished after 200 time steps
# 254 episode: finished after 200 time steps
# 255 episode: finished after 148 time steps
# 256 episode: finished after 200 time steps
# 257 episode: finished after 200 time steps
# 258 episode: finished after 200 time steps
# 259 episode: finished after 200 time steps
# 260 episode: finished after 180 time steps
# 261 episode: finished after 200 time steps
# 262 episode: finished after 62 time steps
# 263 episode: finished after 200 time steps
# 264 episode: finished after 200 time steps
# 265 episode: finished after 200 time steps
# 266 episode: finished after 150 time steps
# 267 episode: finished after 103 time steps
# 268 episode: finished after 142 time steps
# 269 episode: finished after 159 time steps
# 270 episode: finished after 200 time steps
# 271 episode: finished after 200 time steps
# 272 episode: finished after 200 time steps
# 273 episode: finished after 129 time steps
# 274 episode: finished after 200 time steps
# 275 episode: finished after 200 time steps
# 276 episode: finished after 144 time steps
# 277 episode: finished after 145 time steps
# 278 episode: finished after 200 time steps
# 279 episode: finished after 200 time steps
# 280 episode: finished after 153 time steps
# 281 episode: finished after 200 time steps
# 282 episode: finished after 200 time steps
# 283 episode: finished after 200 time steps
# 284 episode: finished after 200 time steps
# 285 episode: finished after 200 time steps
# 286 episode: finished after 200 time steps
# 287 episode: finished after 200 time steps
# 288 episode: finished after 200 time steps
# 289 episode: finished after 200 time steps
# 290 episode: finished after 97 time steps
# 291 episode: finished after 200 time steps
# 292 episode: finished after 200 time steps
# 293 episode: finished after 200 time steps
# 294 episode: finished after 200 time steps
# 295 episode: finished after 199 time steps
# 296 episode: finished after 200 time steps
# 297 episode: finished after 200 time steps
# 298 episode: finished after 200 time steps
# 299 episode: finished after 200 time steps
# 300 episode: finished after 200 time steps
# 10回成功
# 301 episode: finished after 200 time steps
